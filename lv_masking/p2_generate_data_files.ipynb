# %% [markdown]
# # Data File Generation
#
# This notebook will be used to create text files of the paths to images/masks for training/testing.

# %%
import os
import glob
import re
import random

# %%
data_dir = "data/new/"
animals = set()
print("-----Available directories:-----")
for directory in sorted(os.listdir(data_dir)):
    animal = re.search(r'\w+ *\d+', directory)
    if animal != None:
        animals.add(animal.group(0))
    print(directory)
    
animals = list(animals)
print("\n-----Available animals:-----")
for animal in animals:
    print(animal, end=', ')
    
images = sorted(glob.glob(data_dir + "**/*CTImg*", recursive=True))
images = list(map(lambda x: x.replace(data_dir,''), images))
masks = sorted(glob.glob(data_dir + "**/*Mask*", recursive=True))
masks = list(map(lambda x: x.replace(data_dir,''), masks))
# Out:
# -----Available directories:-----
# .ipynb_checkpoints
# PPC 02 Baseline
# PPC 02 PostGel
# PPC 02 PostGel7D
# PPC 02 PostMI
# PPC 02 PostMI5D
# PPC 03 Baseline
# PPC 03 PostGel
# PPC 03 PostGel7D
# PPC 03 PostMI
# PPC 03 PostMI5D
# PPC 04 Baseline
# PPC 04 PostGel
# PPC 04 PostGel7D
# PPC 04 PostMI
# PPC 04 PostMI5D
# PPC 05 Baseline
# PPC 05 PostGel
# PPC 05 PostGel7D
# PPC 05 PostMI
# PPC 05 PostMI5D
# PPC 06 Baseline
# PPC 06 PostGel
# PPC 06 PostGel7D
# PPC 06 PostMI
# PPC 06 PostMI5D
# PPC 07 Baseline
# PPC 07 PostGel
# PPC 07 PostGel7D
# PPC 07 PostMI
# PPC 07 PostMI5D
# PPC 08 Baseline
# PPC 08 PostGel
# PPC 08 PostGel7D
# PPC 08 PostMI
# PPC 08 PostMI5D
# PPC 09 Baseline
# PPC 09 PostGel
# PPC 09 PostGel7D
# PPC 09 PostMI
# PPC 09 PostMI5D
# PPC 11 Baseline
# PPC 11 PostGel
# PPC 11 PostGel7D
# PPC 11 PostMI
# PPC 11 PostMI5D
# PPC 12 Baseline
# PPC 12 PostGel
# PPC 12 PostGel7D
# PPC 12 PostMI
# PPC 12 PostMI5D
# PPC 13 Baseline
# PPC 13 PostGel
# PPC 13 PostGel7D
# PPC 13 PostMI
# PPC 13 PostMI5D
# PPC 14 Baseline
# PPC 14 PostGel
# PPC 14 PostGel7D
# PPC 14 PostMI
# PPC 14 PostMI5D
# PSEA12 PostGel
# PSEA12 PostMI
# PSEA13 Baseline
# PSEA13 PostGel
# PSEA13 PostMI
# PSEA14 Baseline
# PSEA14 PostGel
# PSEA18 Baseline
# PSEA18 PostGel
# PSEA18 PostMI
# PSEA20 PostGel
# PSEA20 PostMI
# PSEA25 Baseline
# PSEA25 PostGel
# PSEA25 PostMI
# PSEA27 Baseline
# PSEA27 PostGel
# PSEA27 PostMI
# test_imgs.txt
# test_masks.txt
# train_imgs.txt
# train_masks.txt
#
# -----Available animals:-----
# PSEA27, PPC 13, PPC 12, PSEA20, PPC 03, PSEA14, PPC 07, PPC 11, PPC 08, PSEA18, PPC 04, PPC 02, PSEA13, PPC 06, PSEA12, PSEA25, PPC 05, PPC 09, PPC 14,

# %%
images
# Out:
# ['PPC 02 Baseline/PPC02_Baseline_CTImg_TimeED.nii',
#  'PPC 02 Baseline/PPC02_Baseline_CTImg_TimeES.nii',
#  'PPC 02 PostGel/PPC02_PostGel_CTImg_TimeED.nii',
#  'PPC 02 PostGel/PPC02_PostGel_CTImg_TimeES.nii',
#  'PPC 02 PostGel7D/PPC02_PostGel7D_CTImg_TimeED.nii',
#  'PPC 02 PostGel7D/PPC02_PostGel7D_CTImg_TimeES.nii',
#  'PPC 02 PostMI/PPC02_PostMI_CTImg_TimeED.nii',
#  'PPC 02 PostMI/PPC02_PostMI_CTImg_TimeES.nii',
#  'PPC 02 PostMI5D/PPC02_PostMI5D_CTImg_TimeED.nii',
#  'PPC 02 PostMI5D/PPC02_PostMI5D_CTImg_TimeES.nii',
#  'PPC 03 Baseline/PPC03_Baseline_CTImg_TimeED.nii',
#  'PPC 03 Baseline/PPC03_Baseline_CTImg_TimeES.nii',
#  'PPC 03 PostGel/PPC03_PostGel_CTImg_TimeED.nii',
#  'PPC 03 PostGel/PPC03_PostGel_CTImg_TimeES.nii',
#  'PPC 03 PostGel7D/PPC03_PostGel7D_CTImg_TimeED.nii',
#  'PPC 03 PostGel7D/PPC03_PostGel7D_CTImg_TimeES.nii',
#  'PPC 03 PostMI/PPC03_PostMI_CTImg_TimeED.nii',
#  'PPC 03 PostMI/PPC03_PostMI_CTImg_TimeES.nii',
#  'PPC 03 PostMI5D/PPC03_PostMI5D_CTImg_TimeED.nii',
#  'PPC 03 PostMI5D/PPC03_PostMI5D_CTImg_TimeES.nii',
#  'PPC 04 Baseline/PPC04_Baseline_CTImg_TimeED.nii',
#  'PPC 04 Baseline/PPC04_Baseline_CTImg_TimeES.nii',
#  'PPC 04 PostGel/PPC04_PostGel_CTImg_TimeED.nii',
#  'PPC 04 PostGel/PPC04_PostGel_CTImg_TimeES.nii',
#  'PPC 04 PostGel7D/PPC04_PostGel7D_CTImg_TimeED.nii',
#  'PPC 04 PostGel7D/PPC04_PostGel7D_CTImg_TimeES.nii',
#  'PPC 04 PostMI/PPC04_PostMI_CTImg_TimeED.nii',
#  'PPC 04 PostMI/PPC04_PostMI_CTImg_TimeES.nii',
#  'PPC 04 PostMI5D/PPC04_PostMI5D_CTImg_TimeED.nii',
#  'PPC 04 PostMI5D/PPC04_PostMI5D_CTImg_TimeES.nii',
#  'PPC 05 Baseline/PPC05_Baseline_CTImg_TimeED.nii',
#  'PPC 05 Baseline/PPC05_Baseline_CTImg_TimeES.nii',
#  'PPC 05 PostGel/PPC05_PostGel_CTImg_TimeED.nii',
#  'PPC 05 PostGel/PPC05_PostGel_CTImg_TimeES.nii',
#  'PPC 05 PostGel7D/PPC05_PostGel7D_CTImg_TimeED.nii',
#  'PPC 05 PostGel7D/PPC05_PostGel7D_CTImg_TimeES.nii',
#  'PPC 05 PostMI/PPC05_PostMI_CTImg_TimeED.nii',
#  'PPC 05 PostMI/PPC05_PostMI_CTImg_TimeES.nii',
#  'PPC 05 PostMI5D/PPC05_PostMI5D_CTImg_TimeED.nii',
#  'PPC 05 PostMI5D/PPC05_PostMI5D_CTImg_TimeES.nii',
#  'PPC 06 Baseline/PPC06_Baseline_CTImg_TimeED.nii',
#  'PPC 06 Baseline/PPC06_Baseline_CTImg_TimeES.nii',
#  'PPC 06 PostGel/PPC06_PostGel_CTImg_TimeED.nii',
#  'PPC 06 PostGel/PPC06_PostGel_CTImg_TimeES.nii',
#  'PPC 06 PostGel7D/PPC06_PostGel7D_CTImg_TimeED.nii',
#  'PPC 06 PostGel7D/PPC06_PostGel7D_CTImg_TimeES.nii',
#  'PPC 06 PostMI/PPC06_PostMI_CTImg_TimeED.nii',
#  'PPC 06 PostMI/PPC06_PostMI_CTImg_TimeES.nii',
#  'PPC 06 PostMI5D/PPC06_PostMI5D_CTImg_TimeED.nii',
#  'PPC 06 PostMI5D/PPC06_PostMI5D_CTImg_TimeES.nii',
#  'PPC 07 Baseline/PPC07_Baseline_CTImg_TimeED.nii',
#  'PPC 07 Baseline/PPC07_Baseline_CTImg_TimeES.nii',
#  'PPC 07 PostGel/PPC07_PostGel_CTImg_TimeED.nii',
#  'PPC 07 PostGel/PPC07_PostGel_CTImg_TimeES.nii',
#  'PPC 07 PostGel7D/PPC07_PostGel7D_CTImg_TimeED.nii',
#  'PPC 07 PostGel7D/PPC07_PostGel7D_CTImg_TimeES.nii',
#  'PPC 07 PostMI/PPC07_PostMI_CTImg_TimeED.nii',
#  'PPC 07 PostMI/PPC07_PostMI_CTImg_TimeES.nii',
#  'PPC 07 PostMI5D/PPC07_PostMI5D_CTImg_TimeED.nii',
#  'PPC 07 PostMI5D/PPC07_PostMI5D_CTImg_TimeES.nii',
#  'PPC 08 Baseline/PPC08_Baseline_CTImg_TimeED.nii',
#  'PPC 08 Baseline/PPC08_Baseline_CTImg_TimeES.nii',
#  'PPC 08 PostGel/PPC08_PostGel_CTImg_TimeED.nii',
#  'PPC 08 PostGel/PPC08_PostGel_CTImg_TimeES.nii',
#  'PPC 08 PostGel7D/PPC08_PostGel7D_CTImg_TimeED.nii',
#  'PPC 08 PostGel7D/PPC08_PostGel7D_CTImg_TimeES.nii',
#  'PPC 08 PostMI/PPC08_PostMI_CTImg_TimeED.nii',
#  'PPC 08 PostMI/PPC08_PostMI_CTImg_TimeES.nii',
#  'PPC 08 PostMI5D/PPC08_PostMI5D_CTImg_TimeED.nii',
#  'PPC 08 PostMI5D/PPC08_PostMI5D_CTImg_TimeES.nii',
#  'PPC 09 Baseline/PPC09_Baseline_CTImg_TimeED.nii',
#  'PPC 09 Baseline/PPC09_Baseline_CTImg_TimeES.nii',
#  'PPC 09 PostGel/PPC09_PostGel_CTImg_TimeED.nii',
#  'PPC 09 PostGel/PPC09_PostGel_CTImg_TimeES.nii',
#  'PPC 09 PostGel7D/PPC09_PostGel7D_CTImg_TimeED.nii',
#  'PPC 09 PostGel7D/PPC09_PostGel7D_CTImg_TimeES.nii',
#  'PPC 09 PostMI/PPC09_PostMI_CTImg_TimeED.nii',
#  'PPC 09 PostMI/PPC09_PostMI_CTImg_TimeES.nii',
#  'PPC 09 PostMI5D/PPC09_PostMI5D_CTImg_TimeED.nii',
#  'PPC 09 PostMI5D/PPC09_PostMI5D_CTImg_TimeES.nii',
#  'PPC 11 Baseline/PPC11_Baseline_CTImg_TimeED.nii',
#  'PPC 11 Baseline/PPC11_Baseline_CTImg_TimeES.nii',
#  'PPC 11 PostGel/PPC11_PostGel_CTImg_TimeED.nii',
#  'PPC 11 PostGel/PPC11_PostGel_CTImg_TimeES.nii',
#  'PPC 11 PostGel7D/PPC11_PostGel7D_CTImg_TimeED.nii',
#  'PPC 11 PostGel7D/PPC11_PostGel7D_CTImg_TimeES.nii',
#  'PPC 11 PostMI/PPC11_PostMI_CTImg_TimeED.nii',
#  'PPC 11 PostMI/PPC11_PostMI_CTImg_TimeES.nii',
#  'PPC 11 PostMI5D/PPC11_PostMI5D_CTImg_TimeED.nii',
#  'PPC 11 PostMI5D/PPC11_PostMI5D_CTImg_TimeES.nii',
#  'PPC 12 Baseline/PPC12_Baseline_CTImg_TimeED.nii',
#  'PPC 12 Baseline/PPC12_Baseline_CTImg_TimeES.nii',
#  'PPC 12 PostGel/PPC12_PostGel_CTImg_TimeED.nii',
#  'PPC 12 PostGel/PPC12_PostGel_CTImg_TimeES.nii',
#  'PPC 12 PostGel7D/PPC12_PostGel7D_CTImg_TimeED.nii',
#  'PPC 12 PostGel7D/PPC12_PostGel7D_CTImg_TimeES.nii',
#  'PPC 12 PostMI/PPC12_PostMI_CTImg_TimeED.nii',
#  'PPC 12 PostMI/PPC12_PostMI_CTImg_TimeES.nii',
#  'PPC 12 PostMI5D/PPC12_PostMI5D_CTImg_TimeED.nii',
#  'PPC 12 PostMI5D/PPC12_PostMI5D_CTImg_TimeES.nii',
#  'PPC 13 Baseline/PPC13_Baseline_CTImg_TimeED.nii',
#  'PPC 13 Baseline/PPC13_Baseline_CTImg_TimeES.nii',
#  'PPC 13 PostGel/PPC13_PostGel_CTImg_TimeED.nii',
#  'PPC 13 PostGel/PPC13_PostGel_CTImg_TimeES.nii',
#  'PPC 13 PostGel7D/PPC13_PostGel7D_CTImg_TimeED.nii',
#  'PPC 13 PostGel7D/PPC13_PostGel7D_CTImg_TimeES.nii',
#  'PPC 13 PostMI/PPC13_PostMI_CTImg_TimeED.nii',
#  'PPC 13 PostMI/PPC13_PostMI_CTImg_TimeES.nii',
#  'PPC 13 PostMI5D/PPC13_PostMI5D_CTImg_TimeED.nii',
#  'PPC 13 PostMI5D/PPC13_PostMI5D_CTImg_TimeES.nii',
#  'PPC 14 Baseline/PPC14_Baseline_CTImg_TimeED.nii',
#  'PPC 14 Baseline/PPC14_Baseline_CTImg_TimeES.nii',
#  'PPC 14 PostGel/PPC14_PostGel_CTImg_TimeED.nii',
#  'PPC 14 PostGel/PPC14_PostGel_CTImg_TimeES.nii',
#  'PPC 14 PostGel7D/PPC14_PostGel7D_CTImg_TimeED.nii',
#  'PPC 14 PostGel7D/PPC14_PostGel7D_CTImg_TimeES.nii',
#  'PPC 14 PostMI/PPC14_PostMI_CTImg_TimeED.nii',
#  'PPC 14 PostMI/PPC14_PostMI_CTImg_TimeES.nii',
#  'PPC 14 PostMI5D/PPC14_PostMI5D_CTImg_TimeED.nii',
#  'PPC 14 PostMI5D/PPC14_PostMI5D_CTImg_TimeES.nii',
#  'PSEA12 PostGel/PSEA12_PostGel_CTImg_Time01.nii',
#  'PSEA12 PostGel/PSEA12_PostGel_CTImg_Time02.nii',
#  'PSEA12 PostGel/PSEA12_PostGel_CTImg_Time03.nii',
#  'PSEA12 PostGel/PSEA12_PostGel_CTImg_Time04.nii',
#  'PSEA12 PostGel/PSEA12_PostGel_CTImg_Time05.nii',
#  'PSEA12 PostGel/PSEA12_PostGel_CTImg_Time06.nii',
#  'PSEA12 PostGel/PSEA12_PostGel_CTImg_Time07.nii',
#  'PSEA12 PostGel/PSEA12_PostGel_CTImg_Time08.nii',
#  'PSEA12 PostGel/PSEA12_PostGel_CTImg_Time09.nii',
#  'PSEA12 PostGel/PSEA12_PostGel_CTImg_Time10.nii',
#  'PSEA12 PostMI/PSEA12_PostMI_CTImg_Time01.nii',
#  'PSEA12 PostMI/PSEA12_PostMI_CTImg_Time02.nii',
#  'PSEA12 PostMI/PSEA12_PostMI_CTImg_Time03.nii',
#  'PSEA12 PostMI/PSEA12_PostMI_CTImg_Time04.nii',
#  'PSEA12 PostMI/PSEA12_PostMI_CTImg_Time05.nii',
#  'PSEA12 PostMI/PSEA12_PostMI_CTImg_Time06.nii',
#  'PSEA12 PostMI/PSEA12_PostMI_CTImg_Time07.nii',
#  'PSEA12 PostMI/PSEA12_PostMI_CTImg_Time08.nii',
#  'PSEA12 PostMI/PSEA12_PostMI_CTImg_Time09.nii',
#  'PSEA12 PostMI/PSEA12_PostMI_CTImg_Time10.nii',
#  'PSEA13 Baseline/PSEA13_Baseline_CTImg_Time01.nii',
#  'PSEA13 Baseline/PSEA13_Baseline_CTImg_Time02.nii',
#  'PSEA13 Baseline/PSEA13_Baseline_CTImg_Time03.nii',
#  'PSEA13 Baseline/PSEA13_Baseline_CTImg_Time04.nii',
#  'PSEA13 Baseline/PSEA13_Baseline_CTImg_Time05.nii',
#  'PSEA13 Baseline/PSEA13_Baseline_CTImg_Time06.nii',
#  'PSEA13 Baseline/PSEA13_Baseline_CTImg_Time07.nii',
#  'PSEA13 Baseline/PSEA13_Baseline_CTImg_Time08.nii',
#  'PSEA13 Baseline/PSEA13_Baseline_CTImg_Time09.nii',
#  'PSEA13 Baseline/PSEA13_Baseline_CTImg_Time10.nii',
#  'PSEA13 PostGel/PSEA13_PostGel_CTImg_Time01.nii',
#  'PSEA13 PostGel/PSEA13_PostGel_CTImg_Time02.nii',
#  'PSEA13 PostGel/PSEA13_PostGel_CTImg_Time03.nii',
#  'PSEA13 PostGel/PSEA13_PostGel_CTImg_Time04.nii',
#  'PSEA13 PostGel/PSEA13_PostGel_CTImg_Time05.nii',
#  'PSEA13 PostGel/PSEA13_PostGel_CTImg_Time06.nii',
#  'PSEA13 PostGel/PSEA13_PostGel_CTImg_Time07.nii',
#  'PSEA13 PostGel/PSEA13_PostGel_CTImg_Time08.nii',
#  'PSEA13 PostGel/PSEA13_PostGel_CTImg_Time09.nii',
#  'PSEA13 PostGel/PSEA13_PostGel_CTImg_Time10.nii',
#  'PSEA13 PostMI/PSEA13_PostMI_CTImg_Time01.nii',
#  'PSEA13 PostMI/PSEA13_PostMI_CTImg_Time02.nii',
#  'PSEA13 PostMI/PSEA13_PostMI_CTImg_Time03.nii',
#  'PSEA13 PostMI/PSEA13_PostMI_CTImg_Time04.nii',
#  'PSEA13 PostMI/PSEA13_PostMI_CTImg_Time05.nii',
#  'PSEA13 PostMI/PSEA13_PostMI_CTImg_Time06.nii',
#  'PSEA13 PostMI/PSEA13_PostMI_CTImg_Time07.nii',
#  'PSEA13 PostMI/PSEA13_PostMI_CTImg_Time08.nii',
#  'PSEA13 PostMI/PSEA13_PostMI_CTImg_Time09.nii',
#  'PSEA13 PostMI/PSEA13_PostMI_CTImg_Time10.nii',
#  'PSEA14 Baseline/PSEA14_Baseline_CTImg_Time01.nii',
#  'PSEA14 Baseline/PSEA14_Baseline_CTImg_Time02.nii',
#  'PSEA14 Baseline/PSEA14_Baseline_CTImg_Time03.nii',
#  'PSEA14 Baseline/PSEA14_Baseline_CTImg_Time04.nii',
#  'PSEA14 Baseline/PSEA14_Baseline_CTImg_Time05.nii',
#  'PSEA14 Baseline/PSEA14_Baseline_CTImg_Time06.nii',
#  'PSEA14 Baseline/PSEA14_Baseline_CTImg_Time07.nii',
#  'PSEA14 Baseline/PSEA14_Baseline_CTImg_Time08.nii',
#  'PSEA18 Baseline/PSEA18_Baseline_CTImg_Time01.nii',
#  'PSEA18 Baseline/PSEA18_Baseline_CTImg_Time02.nii',
#  'PSEA18 Baseline/PSEA18_Baseline_CTImg_Time03.nii',
#  'PSEA18 Baseline/PSEA18_Baseline_CTImg_Time04.nii',
#  'PSEA18 Baseline/PSEA18_Baseline_CTImg_Time05.nii',
#  'PSEA18 Baseline/PSEA18_Baseline_CTImg_Time06.nii',
#  'PSEA18 Baseline/PSEA18_Baseline_CTImg_Time07.nii',
#  'PSEA18 Baseline/PSEA18_Baseline_CTImg_Time08.nii',
#  'PSEA18 Baseline/PSEA18_Baseline_CTImg_Time09.nii',
#  'PSEA18 PostGel/PSEA18_PostGel_CTImg_Time01.nii',
#  'PSEA18 PostGel/PSEA18_PostGel_CTImg_Time02.nii',
#  'PSEA18 PostGel/PSEA18_PostGel_CTImg_Time03.nii',
#  'PSEA18 PostGel/PSEA18_PostGel_CTImg_Time04.nii',
#  'PSEA18 PostGel/PSEA18_PostGel_CTImg_Time05.nii',
#  'PSEA18 PostGel/PSEA18_PostGel_CTImg_Time06.nii',
#  'PSEA18 PostGel/PSEA18_PostGel_CTImg_Time07.nii',
#  'PSEA18 PostGel/PSEA18_PostGel_CTImg_Time08.nii',
#  'PSEA18 PostGel/PSEA18_PostGel_CTImg_Time09.nii',
#  'PSEA18 PostMI/PSEA18_PostMI_CTImg_Time01.nii',
#  'PSEA18 PostMI/PSEA18_PostMI_CTImg_Time02.nii',
#  'PSEA18 PostMI/PSEA18_PostMI_CTImg_Time03.nii',
#  'PSEA18 PostMI/PSEA18_PostMI_CTImg_Time04.nii',
#  'PSEA18 PostMI/PSEA18_PostMI_CTImg_Time05.nii',
#  'PSEA18 PostMI/PSEA18_PostMI_CTImg_Time06.nii',
#  'PSEA18 PostMI/PSEA18_PostMI_CTImg_Time07.nii',
#  'PSEA18 PostMI/PSEA18_PostMI_CTImg_Time08.nii',
#  'PSEA20 PostGel/PSEA20_PostGel_CTImg_Time01.nii',
#  'PSEA20 PostGel/PSEA20_PostGel_CTImg_Time02.nii',
#  'PSEA20 PostGel/PSEA20_PostGel_CTImg_Time03.nii',
#  'PSEA20 PostGel/PSEA20_PostGel_CTImg_Time04.nii',
#  'PSEA20 PostGel/PSEA20_PostGel_CTImg_Time05.nii',
#  'PSEA20 PostGel/PSEA20_PostGel_CTImg_Time06.nii',
#  'PSEA20 PostGel/PSEA20_PostGel_CTImg_Time07.nii',
#  'PSEA20 PostGel/PSEA20_PostGel_CTImg_Time08.nii',
#  'PSEA20 PostGel/PSEA20_PostGel_CTImg_Time09.nii',
#  'PSEA20 PostGel/PSEA20_PostGel_CTImg_Time10.nii',
#  'PSEA20 PostMI/PSEA20_PostMI_CTImg_Time01.nii',
#  'PSEA20 PostMI/PSEA20_PostMI_CTImg_Time02.nii',
#  'PSEA20 PostMI/PSEA20_PostMI_CTImg_Time03.nii',
#  'PSEA20 PostMI/PSEA20_PostMI_CTImg_Time04.nii',
#  'PSEA20 PostMI/PSEA20_PostMI_CTImg_Time05.nii',
#  'PSEA20 PostMI/PSEA20_PostMI_CTImg_Time06.nii',
#  'PSEA20 PostMI/PSEA20_PostMI_CTImg_Time07.nii',
#  'PSEA20 PostMI/PSEA20_PostMI_CTImg_Time08.nii',
#  'PSEA20 PostMI/PSEA20_PostMI_CTImg_Time09.nii',
#  'PSEA20 PostMI/PSEA20_PostMI_CTImg_Time10.nii',
#  'PSEA25 Baseline/PSEA25_Baseline_CTImg_Time01.nii',
#  'PSEA25 Baseline/PSEA25_Baseline_CTImg_Time02.nii',
#  'PSEA25 Baseline/PSEA25_Baseline_CTImg_Time03.nii',
#  'PSEA25 Baseline/PSEA25_Baseline_CTImg_Time04.nii',
#  'PSEA25 Baseline/PSEA25_Baseline_CTImg_Time05.nii',
#  'PSEA25 Baseline/PSEA25_Baseline_CTImg_Time06.nii',
#  'PSEA25 Baseline/PSEA25_Baseline_CTImg_Time07.nii',
#  'PSEA25 Baseline/PSEA25_Baseline_CTImg_Time08.nii',
#  'PSEA25 Baseline/PSEA25_Baseline_CTImg_Time09.nii',
#  'PSEA25 Baseline/PSEA25_Baseline_CTImg_Time10.nii',
#  'PSEA25 PostGel/PSEA25_PostGel_CTImg_Time01.nii',
#  'PSEA25 PostGel/PSEA25_PostGel_CTImg_Time02.nii',
#  'PSEA25 PostGel/PSEA25_PostGel_CTImg_Time03.nii',
#  'PSEA25 PostGel/PSEA25_PostGel_CTImg_Time04.nii',
#  'PSEA25 PostGel/PSEA25_PostGel_CTImg_Time05.nii',
#  'PSEA25 PostGel/PSEA25_PostGel_CTImg_Time06.nii',
#  'PSEA25 PostGel/PSEA25_PostGel_CTImg_Time07.nii',
#  'PSEA25 PostGel/PSEA25_PostGel_CTImg_Time08.nii',
#  'PSEA25 PostGel/PSEA25_PostGel_CTImg_Time09.nii',
#  'PSEA25 PostGel/PSEA25_PostGel_CTImg_Time10.nii',
#  'PSEA25 PostMI/PSEA25_PostMI_CTImg_Time01.nii',
#  'PSEA25 PostMI/PSEA25_PostMI_CTImg_Time02.nii',
#  'PSEA25 PostMI/PSEA25_PostMI_CTImg_Time03.nii',
#  'PSEA25 PostMI/PSEA25_PostMI_CTImg_Time04.nii',
#  'PSEA25 PostMI/PSEA25_PostMI_CTImg_Time05.nii',
#  'PSEA25 PostMI/PSEA25_PostMI_CTImg_Time06.nii',
#  'PSEA25 PostMI/PSEA25_PostMI_CTImg_Time07.nii',
#  'PSEA25 PostMI/PSEA25_PostMI_CTImg_Time08.nii',
#  'PSEA25 PostMI/PSEA25_PostMI_CTImg_Time09.nii',
#  'PSEA25 PostMI/PSEA25_PostMI_CTImg_Time10.nii',
#  'PSEA27 Baseline/PSEA27_Baseline_CTImg_Time01.nii',
#  'PSEA27 Baseline/PSEA27_Baseline_CTImg_Time02.nii',
#  'PSEA27 Baseline/PSEA27_Baseline_CTImg_Time03.nii',
#  'PSEA27 Baseline/PSEA27_Baseline_CTImg_Time04.nii',
#  'PSEA27 Baseline/PSEA27_Baseline_CTImg_Time05.nii',
#  'PSEA27 Baseline/PSEA27_Baseline_CTImg_Time06.nii',
#  'PSEA27 Baseline/PSEA27_Baseline_CTImg_Time07.nii',
#  'PSEA27 Baseline/PSEA27_Baseline_CTImg_Time08.nii',
#  'PSEA27 Baseline/PSEA27_Baseline_CTImg_Time09.nii',
#  'PSEA27 Baseline/PSEA27_Baseline_CTImg_Time10.nii',
#  'PSEA27 PostGel/PSEA27_PostGel_CTImg_Time01.nii',
#  'PSEA27 PostGel/PSEA27_PostGel_CTImg_Time02.nii',
#  'PSEA27 PostGel/PSEA27_PostGel_CTImg_Time03.nii',
#  'PSEA27 PostGel/PSEA27_PostGel_CTImg_Time04.nii',
#  'PSEA27 PostGel/PSEA27_PostGel_CTImg_Time05.nii',
#  'PSEA27 PostGel/PSEA27_PostGel_CTImg_Time06.nii',
#  'PSEA27 PostGel/PSEA27_PostGel_CTImg_Time07.nii',
#  'PSEA27 PostGel/PSEA27_PostGel_CTImg_Time08.nii',
#  'PSEA27 PostGel/PSEA27_PostGel_CTImg_Time09.nii',
#  'PSEA27 PostGel/PSEA27_PostGel_CTImg_Time10.nii',
#  'PSEA27 PostMI/PSEA27_PostMI_CTImg_Time01.nii',
#  'PSEA27 PostMI/PSEA27_PostMI_CTImg_Time02.nii',
#  'PSEA27 PostMI/PSEA27_PostMI_CTImg_Time03.nii',
#  'PSEA27 PostMI/PSEA27_PostMI_CTImg_Time04.nii',
#  'PSEA27 PostMI/PSEA27_PostMI_CTImg_Time05.nii',
#  'PSEA27 PostMI/PSEA27_PostMI_CTImg_Time06.nii',
#  'PSEA27 PostMI/PSEA27_PostMI_CTImg_Time07.nii',
#  'PSEA27 PostMI/PSEA27_PostMI_CTImg_Time08.nii',
#  'PSEA27 PostMI/PSEA27_PostMI_CTImg_Time09.nii',
#  'PSEA27 PostMI/PSEA27_PostMI_CTImg_Time10.nii']

# %%
def check_data_alignment(images, masks):
    """Checks whether the images/masks are aligned properly."""
    for (image, mask) in zip(images, masks):
        image_sub = re.sub(r'CTImg', '', image)
        mask_sub = re.sub(r'Mask', '', mask)
        if image_sub != mask_sub:
            print(image)
            print(mask)
            return False
    return True

print('Is the data aligned: ', check_data_alignment(images, masks))
# Out:
# Is the data aligned:  True

# %%
animals
# Out:
# ['PSEA27',
#  'PPC 13',
#  'PPC 12',
#  'PSEA20',
#  'PPC 03',
#  'PSEA14',
#  'PPC 07',
#  'PPC 11',
#  'PPC 08',
#  'PSEA18',
#  'PPC 04',
#  'PPC 02',
#  'PSEA13',
#  'PPC 06',
#  'PSEA12',
#  'PSEA25',
#  'PPC 05',
#  'PPC 09',
#  'PPC 14']

# %%
# Change these lists to change train/test distribution
train_animals = random.sample(animals, 15)
test_animals =  [animal for animal in animals if animal not in train_animals]
print(train_animals)
print(test_animals)
# Out:
# ['PSEA18', 'PPC 05', 'PPC 04', 'PPC 07', 'PSEA12', 'PPC 09', 'PPC 12', 'PPC 11', 'PPC 08', 'PSEA13', 'PPC 06', 'PSEA14', 'PSEA20', 'PPC 02', 'PPC 14']
# ['PSEA27', 'PPC 13', 'PPC 03', 'PSEA25']

# %%
len(set(train_animals + test_animals))
# Out:
# 19

# %%
len(animals)
# Out:
# 19

# %%
def paths_to_file(images, masks, animals, group):
    """Returns the images and masks as a dictionary for specific animals."""
    filtered_images = []
    filtered_masks = []
    for animal in animals:
        filtered_images.extend(filter(lambda x: animal in x, images))
        filtered_masks.extend(filter(lambda x: animal in x, masks))
        
    with open(data_dir + group + '_imgs.txt', 'w') as f:
        f.writelines("%s\n" % image for image in filtered_images)
    with open(data_dir + group + '_masks.txt', 'w') as f:
        f.writelines("%s\n" % mask for mask in filtered_masks)

# %%
paths_to_file(images, masks, train_animals, 'train')
paths_to_file(images, masks, test_animals, 'test')
